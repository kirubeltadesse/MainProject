# %%
import json
import random
import numpy as np

# %%
with open('words.json') as datafile:
    data = json.load(datafile)

# %%
len(data)
# Out:
# 3

# %%
import pandas as pd

# %%
df = pd.read_excel('univ_college_websites.xlsx', sheet_name="Sheet1", index='URL', columns=['School Name','City','State'])

# %%
df.columns.all
# Out:
# <bound method Index.all of Index([u'School Name', u'URL', u'City', u'State'], dtype='object')>

# %%
df
# Out:
#                                             School Name  \
# 0                                  University of Alaska
# 1                              Alaska Christian College
# 2                       National Park Community College
# 3                        University of Alaska Fairbanks
# 4                   University of Arkansas - Fort Smith
# 5                                Alabama A&M University
# 6                               Athens State University
# 7                                     Auburn University
# 8                       Auburn University at Montgomery
# 9                           Birmingham-Southern College
# 10                            Calhoun Community College
# 11                   Enterprise State Community College
# 12                     Faulkner State Community College
# 13                      Gadsden State Community College
# 14                                   Huntingdon College
# 15                        Jacksonville State University
# 16                 Lurleen B. Wallace Community College
# 17                             University of Montevallo
# 18                  Northeast Alabama Community College
# 19                   Northwest-Shoals Community College
# 20                                   Oakwood University
# 21                                   Samford University
# 22                           Southeastern Bible College
# 23                          University of South Alabama
# 24                     Trenholm State Technical College
# 25                                      Troy University
# 26                                  Tuskegee University
# 27                                University of Alabama
# 28                  University of Alabama at Birmingham
# 29                  University of Alabama in Huntsville
# ...                                                 ...
# 1900                   University of Wisconsin Superior
# 1901                 University of Wisconsin Whitewater
# 1902                                 Viterbo University
# 1903                  Waukesha County Technical College
# 1904                   University of Wisconsin, Madison
# 1905             Wisconsin Indianhead Technical College
# 1906                         Wisconsin Lutheran College
# 1907                 Wisconsin Technical College System
# 1908                          Western Technical College
# 1909                  American Public University System
# 1910                                 Concord University
# 1911  Eastern West Virgina Community and Technical C...
# 1912                          Fairmont State University
# 1913                                Marshall University
# 1914                             Ohio Valley University
# 1915           Pierpont Community and Technical College
# 1916                                Shepherd University
# 1917                           University of Charleston
# 1918                            West Liberty University
# 1919                         Wheeling Jesuit University
# 1920           West Virginia Northern Community College
# 1921                     West Virginia State University
# 1922                           West Virginia University
# 1923                     West Virginia Wesleyan College
# 1924                                     Casper College
# 1925                            Central Wyoming College
# 1926                 National Outdoor Leadership School
# 1927                                  Northwest College
# 1928        Northern Wyoming Community College District
# 1929                              University of Wyoming
#
#                               URL                       City State
# 0               http://alaska.edu                  Anchorage    AK
# 1             http://alaskacc.edu                   Soldotna    AK
# 2                 http://npcc.edu  Hot Springs National Park    AK
# 3                  http://uaf.edu                  Fairbanks    AK
# 4                 http://uafs.edu                 Fort Smith    AK
# 5                 http://aamu.edu                  Huntville    AL
# 6               http://athens.edu                     Athens    AL
# 7               http://auburn.edu                     Auburn    AL
# 8                  http://aum.edu                 Montgomery    AL
# 9                  http://bsc.edu                 Birmingham    AL
# 10             http://calhoun.edu                    Decatur    AL
# 11                http://escc.edu                 Enterprise    AL
# 12       http://faulknerstate.edu                Bay Minette    AL
# 13        http://gadsdenstate.edu                    Gadsden    AL
# 14          http://huntingdon.edu                 Montgomery    AL
# 15                 http://jsu.edu               Jacksonville    AL
# 16               http://lbwcc.edu                  Andalusia    AL
# 17          http://montevallo.edu                 Montevallo    AL
# 18                http://nacc.edu                 Rainsville    AL
# 19               http://nwscc.edu              Muscle Shoals    AL
# 20             http://oakwood.edu                 Huntsville    AL
# 21             http://samford.edu                 Birmingham    AL
# 22                http://sebc.edu                 Birmingham    AL
# 23        http://southalabama.edu                     Mobile    AL
# 24       http://trenholmstate.edu                 Montgomery    AL
# 25                http://troy.edu                       Troy    AL
# 26            http://tuskegee.edu                   Tuskegee    AL
# 27                  http://ua.edu                 Tuscaloosa    AL
# 28                 http://uab.edu                 Birmingham    AL
# 29                 http://uah.edu                 Huntsville    AL
# ...                           ...                        ...   ...
# 1900           http://uwsuper.edu                   Superior    WI
# 1901               http://uww.edu                 Whitewater    WI
# 1902           http://viterbo.edu                  La Crosse    WI
# 1903              http://wctc.edu                   Pewaukee    WI
# 1904              http://wisc.edu                    Madison    WI
# 1905              http://witc.edu                 Shell Lake    WI
# 1906               http://wlc.edu                  Milwaukee    WI
# 1907         http://wtcsystem.edu                    Madison    WI
# 1908         http://westerntc.edu                  La Crosse    WI
# 1909              http://apus.edu               Charles Town    WV
# 1910           http://concord.edu                     Athens    WV
# 1911         http://easternwv.edu                 Moorefield    WV
# 1912     http://fairmontstate.edu                   Fairmont    WV
# 1913          http://marshall.edu                 Huntington    WV
# 1914               http://ovu.edu                     Vienna    WV
# 1915          http://pierpont.edu                   Fairmont    WV
# 1916          http://shepherd.edu              Shepherdstown    WV
# 1917              http://ucwv.edu                 Charleston    WV
# 1918       http://westliberty.edu                   Wheeling    WV
# 1919               http://wju.edu                   Wheeling    WV
# 1920             http://wvncc.edu                   Wheeling    WV
# 1921          http://wvstateu.edu                  Institute    WV
# 1922               http://wvu.edu                 Morgantown    WV
# 1923              http://wvwc.edu                 Buckhannon    WV
# 1924     http://caspercollege.edu                     Casper    WY
# 1925               http://cwc.edu                   Riverton    WY
# 1926              http://nols.edu                     Lander    WY
# 1927  http://northwestcollege.edu                     Powell    WY
# 1928          http://sheridan.edu                   Sheridan    WY
# 1929              http://uwyo.edu                    Laramie    WY
#
# [1930 rows x 4 columns]

# %%
d2 = df.set_index('URL')

# %%
NEWDF
# Out:
# School Name
# University of Alaska                                              http://alaska.edu
# Alaska Christian College                                        http://alaskacc.edu
# National Park Community College                                     http://npcc.edu
# University of Alaska Fairbanks                                       http://uaf.edu
# University of Arkansas - Fort Smith                                 http://uafs.edu
# Alabama A&M University                                              http://aamu.edu
# Athens State University                                           http://athens.edu
# Auburn University                                                 http://auburn.edu
# Auburn University at Montgomery                                      http://aum.edu
# Birmingham-Southern College                                          http://bsc.edu
# Calhoun Community College                                        http://calhoun.edu
# Enterprise State Community College                                  http://escc.edu
# Faulkner State Community College                           http://faulknerstate.edu
# Gadsden State Community College                             http://gadsdenstate.edu
# Huntingdon College                                            http://huntingdon.edu
# Jacksonville State University                                        http://jsu.edu
# Lurleen B. Wallace Community College                               http://lbwcc.edu
# University of Montevallo                                      http://montevallo.edu
# Northeast Alabama Community College                                 http://nacc.edu
# Northwest-Shoals Community College                                 http://nwscc.edu
# Oakwood University                                               http://oakwood.edu
# Samford University                                               http://samford.edu
# Southeastern Bible College                                          http://sebc.edu
# University of South Alabama                                 http://southalabama.edu
# Trenholm State Technical College                           http://trenholmstate.edu
# Troy University                                                     http://troy.edu
# Tuskegee University                                             http://tuskegee.edu
# University of Alabama                                                 http://ua.edu
# University of Alabama at Birmingham                                  http://uab.edu
# University of Alabama in Huntsville                                  http://uah.edu
#                                                                    ...
# University of Wisconsin Superior                                 http://uwsuper.edu
# University of Wisconsin Whitewater                                   http://uww.edu
# Viterbo University                                               http://viterbo.edu
# Waukesha County Technical College                                   http://wctc.edu
# University of Wisconsin, Madison                                    http://wisc.edu
# Wisconsin Indianhead Technical College                              http://witc.edu
# Wisconsin Lutheran College                                           http://wlc.edu
# Wisconsin Technical College System                             http://wtcsystem.edu
# Western Technical College                                      http://westerntc.edu
# American Public University System                                   http://apus.edu
# Concord University                                               http://concord.edu
# Eastern West Virgina Community and Technical College           http://easternwv.edu
# Fairmont State University                                  http://fairmontstate.edu
# Marshall University                                             http://marshall.edu
# Ohio Valley University                                               http://ovu.edu
# Pierpont Community and Technical College                        http://pierpont.edu
# Shepherd University                                             http://shepherd.edu
# University of Charleston                                            http://ucwv.edu
# West Liberty University                                      http://westliberty.edu
# Wheeling Jesuit University                                           http://wju.edu
# West Virginia Northern Community College                           http://wvncc.edu
# West Virginia State University                                  http://wvstateu.edu
# West Virginia University                                             http://wvu.edu
# West Virginia Wesleyan College                                      http://wvwc.edu
# Casper College                                             http://caspercollege.edu
# Central Wyoming College                                              http://cwc.edu
# National Outdoor Leadership School                                  http://nols.edu
# Northwest College                                       http://northwestcollege.edu
# Northern Wyoming Community College District                     http://sheridan.edu
# University of Wyoming                                               http://uwyo.edu
# Name: URL, dtype: object

# %%
d2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-a82732c80525> in <module>()
# ----> 1 d2['URL']
#
# /home/kirubel/src/pandas/pandas/core/frame.pyc in __getitem__(self, key)
#    1969             return self._getitem_multilevel(key)
#    1970         else:
# -> 1971             return self._getitem_column(key)
#    1972
#    1973     def _getitem_column(self, key):
#
# /home/kirubel/src/pandas/pandas/core/frame.pyc in _getitem_column(self, key)
#    1976         # get column
#    1977         if self.columns.is_unique:
# -> 1978             return self._get_item_cache(key)
#    1979
#    1980         # duplicate columns & possible reduce dimensionality
#
# /home/kirubel/src/pandas/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1089         res = cache.get(item)
#    1090         if res is None:
# -> 1091             values = self._data.get(item)
#    1092             res = self._box_item_values(item, values)
#    1093             cache[item] = res
#
# /home/kirubel/src/pandas/pandas/core/internals.pyc in get(self, item, fastpath)
#    3209
#    3210             if not isnull(item):
# -> 3211                 loc = self.items.get_loc(item)
#    3212             else:
#    3213                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/kirubel/src/pandas/pandas/core/index.pyc in get_loc(self, key, method, tolerance)
#    1761                 raise ValueError('tolerance argument only valid if using pad, '
#    1762                                  'backfill or nearest lookups')
# -> 1763             return self._engine.get_loc(_values_from_object(key))
#    1764
#    1765         indexer = self.get_indexer([key], method=method,
#
# /home/kirubel/src/pandas/pandas/index.pyx in pandas.index.IndexEngine.get_loc()
#     135             util.set_value_at(arr, loc, value)
#     136
# --> 137     cpdef get_loc(self, object val):
#     138         if is_definitely_invalid_key(val):
#     139             raise TypeError
#
# /home/kirubel/src/pandas/pandas/index.pyx in pandas.index.IndexEngine.get_loc()
#     155
#     156         try:
# --> 157             return self.mapping.get_item(val)
#     158         except TypeError:
#     159             raise KeyError(val)
#
# /home/kirubel/src/pandas/pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item()
#     666         self.table = NULL
#     667
# --> 668     cpdef get_item(self, object val):
#     669         cdef khiter_t k
#     670         if val != val or val is None:
#
# /home/kirubel/src/pandas/pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item()
#     674             return self.table.vals[k]
#     675         else:
# --> 676             raise KeyError(val)
#     677
#     678     def get_iter_test(self, object key, Py_ssize_t iterations):
#
# KeyError: 'URL'

# %%
type(d2)
# Out:
# pandas.core.frame.DataFrame

# %%
mylist = np.array(NEWDF)

# %%
len(mylist[:100])
# Out:
# 100

# %%
newdf = pd.DataFrame(data=mylist)

# %%
newdf
# Out:
#                                 0
# 0               http://alaska.edu
# 1             http://alaskacc.edu
# 2                 http://npcc.edu
# 3                  http://uaf.edu
# 4                 http://uafs.edu
# 5                 http://aamu.edu
# 6               http://athens.edu
# 7               http://auburn.edu
# 8                  http://aum.edu
# 9                  http://bsc.edu
# 10             http://calhoun.edu
# 11                http://escc.edu
# 12       http://faulknerstate.edu
# 13        http://gadsdenstate.edu
# 14          http://huntingdon.edu
# 15                 http://jsu.edu
# 16               http://lbwcc.edu
# 17          http://montevallo.edu
# 18                http://nacc.edu
# 19               http://nwscc.edu
# 20             http://oakwood.edu
# 21             http://samford.edu
# 22                http://sebc.edu
# 23        http://southalabama.edu
# 24       http://trenholmstate.edu
# 25                http://troy.edu
# 26            http://tuskegee.edu
# 27                  http://ua.edu
# 28                 http://uab.edu
# 29                 http://uah.edu
# ...                           ...
# 1900           http://uwsuper.edu
# 1901               http://uww.edu
# 1902           http://viterbo.edu
# 1903              http://wctc.edu
# 1904              http://wisc.edu
# 1905              http://witc.edu
# 1906               http://wlc.edu
# 1907         http://wtcsystem.edu
# 1908         http://westerntc.edu
# 1909              http://apus.edu
# 1910           http://concord.edu
# 1911         http://easternwv.edu
# 1912     http://fairmontstate.edu
# 1913          http://marshall.edu
# 1914               http://ovu.edu
# 1915          http://pierpont.edu
# 1916          http://shepherd.edu
# 1917              http://ucwv.edu
# 1918       http://westliberty.edu
# 1919               http://wju.edu
# 1920             http://wvncc.edu
# 1921          http://wvstateu.edu
# 1922               http://wvu.edu
# 1923              http://wvwc.edu
# 1924     http://caspercollege.edu
# 1925               http://cwc.edu
# 1926              http://nols.edu
# 1927  http://northwestcollege.edu
# 1928          http://sheridan.edu
# 1929              http://uwyo.edu
#
# [1930 rows x 1 columns]

# %%
MyJson = newdf.to_json('NewJson', date_format='iso')

# %%
MyJson

# %%
# %load Analysis.py
import pandas as pd
import numpy as np
import re
import collections
from mpldatacursor import datacursor

class analysis():
	def __init__(self, num_data):
		self.num_data = num_data

	# clean up a row data 
	def clean_up(self, file_name): 
		with open(file_name) as infile:
			contents = infile.read()
			data = contents.replace('%20', ' ')
			data = data.replace('%2F%2F','://')
			info = data.replace(';','\n')
			info = info.replace('%3D%3D%3D%3D','\n')
			info1 = info.replace('%3A','')
			# f = open("data.txt","a+")
			# f.write(info1 +"\n")
			# f.close()
			self.prepare(info1)

	# change to list with in a dictionary 
	def prepare(self, file_name, from_file=False):
		collection = []
		data= collections.defaultdict(dict) 
		count_num_data = 0

		if from_file:
			with open(file_name,'r') as l_file:	
				content = l_file.read()
		else:
			content = file_name

		# convert the data into one hot list
		line = content.split('\n')
		for each in line:
			values = each.split(':')
			# print values, len(values)
			if len(values) == 3:
				key, value_1, value_2 = values
				value = value_1+":"+ value_2
				if key == 'web address':
					catagory = value
			elif len(values) == 2:
				key, value = values
			else:                   
			#	if count_num_data %100 == 0:
			#	print key, value, len(value)
				pass
				if key == 'Waterfall view':
					pattern = r'[0-9][0-9]'
					if re.search(pattern, value):
						x = re.findall(pattern,value)
						rep = re.compile(r'\s+')
						time = re.sub(rep,'',str(x[:3]).replace("'",""))
						
						value = time.replace('18','2018').replace('[', '').replace(']','').replace(',','-')
						key = 'date'
					count_num_data += 1 

			
			data[catagory].setdefault(key,[]).append(value)
			
		cleaned_dict =  dict(data)
		for web in cleaned_dict.keys():
			#replace empty value with np.nan
			del cleaned_dict[web]['Waterfall view']
			del cleaned_dict[web]['web address']
			for x in cleaned_dict[web].keys():
				if '' in cleaned_dict[web][x]:
					for y in cleaned_dict[web][x]:
						cleaned_dict[web][x] = np.nan
			if cleaned_dict[web].has_key(''):
				del cleaned_dict[web]['']
			else:
				pass
		
		print "The number of data collected is: ", count_num_data
		return cleaned_dict
	
	def select(self, dataframe, param):
		dfT = dataframe.transpose() 

		# conver to frame
		df_2 = pd.DataFrame(data=dfT[param]).dropna()
		s = df_2.apply(lambda x: pd.Series(x[param]), axis = 1).transpose().max()
		return s	

	# produce tabel, chart, and graph
	def plot(self, dataframe):
		return dataframe.plot()
	
	def prop(self, dataframe):
		return dataframe.columns
	
		
test = analysis(1)
value =  test.prepare('data.csv', True)
#test.clean_up('test_result.txt')

'''
df2 = pd.DataFrame.from_dict({(i,j):value[i][j]
							for i in value.keys()
							for j in value[i].keys()},
							orient = 'index')
'''

df = pd.DataFrame(data=value)
New = test.select(df, u'Speed Index')
data = test.select(df, u'date')

website_list = pd.read_html("https://en.wikipedia.org/wiki/List_of_most_popular_websites")

for each in website_list:
    web_address = pd.DataFrame(data=each[1], index=each[1])

web_address.to_csv('alexa_weblist.csv')
#print New.describe()
#print data.describe()

dfT = df.transpose()

# conver to frame
df_2 =pd.DataFrame(data=dfT[u'Speed Index']).dropna()
s = df_2.apply(lambda x: pd.Series(x[u'Speed Index']), axis = 1).transpose().max()
# print s

#print df[:1].describe()
#df_replace = dfT[:5][u'Speed Index']
#print dfT.describe()
#print dfT[:][u'Speed Index'].mean()
# Out:
# The number of data collected is:  6818

# %%
# creating my own dataset
df = pd.DataFrame(data=[[[-0.07, -2.9, -2.44],1,1],[[-1.52, -0.35, 0.1],1,2,],[[-0.17, 0.57, -0.65],1,3],[[-0.82, -1.06, 0.47],2,1],[[0.79, 1.35, -0.09],2,2],[[1.17, 1.14, -1.79],2,3]], columns=['samples', 'subject', 'trial_num'])

# %%
df
# Out:
#                 samples  subject  trial_num
# 0  [-0.07, -2.9, -2.44]        1          1
# 1   [-1.52, -0.35, 0.1]        1          2
# 2  [-0.17, 0.57, -0.65]        1          3
# 3  [-0.82, -1.06, 0.47]        2          1
# 4   [0.79, 1.35, -0.09]        2          2
# 5   [1.17, 1.14, -1.79]        2          3

# %%
s = df.apply(lambda x: pd.Series(x['samples']), axis=1).transpose().max()

# %%
s
# Out:
# 0   -0.07
# 1    0.10
# 2    0.57
# 3    0.47
# 4    1.35
# 5    1.17
# dtype: float64

# %%
s.name = 'sample'

# %%
df.drop('samples', axis=1).join(s)
# Out:
#    subject  trial_num  sample
# 0        1          1   -0.07
# 1        1          2    0.10
# 2        1          3    0.57
# 3        2          1    0.47
# 4        2          2    1.35
# 5        2          3    1.17

# %%
s = df.apply(lambda x: pd.Series(x['samples']), axis=1).stack().reset_index(level=1, drop=True)

# %%
s
# Out:
# 0   -0.07
# 0   -2.90
# 0   -2.44
# 1   -1.52
# 1   -0.35
# 1    0.10
# 2   -0.17
# 2    0.57
# 2   -0.65
# 3   -0.82
# 3   -1.06
# 3    0.47
# 4    0.79
# 4    1.35
# 4   -0.09
# 5    1.17
# 5    1.14
# 5   -1.79
# dtype: float64

# %%
s.name = 'sample'

# %%
df.drop('samples', axis=1).join(s)
# Out:
#    subject  trial_num  sample
# 0        1          1   -0.07
# 0        1          1   -2.90
# 0        1          1   -2.44
# 1        1          2   -1.52
# 1        1          2   -0.35
# 1        1          2    0.10
# 2        1          3   -0.17
# 2        1          3    0.57
# 2        1          3   -0.65
# 3        2          1   -0.82
# 3        2          1   -1.06
# 3        2          1    0.47
# 4        2          2    0.79
# 4        2          2    1.35
# 4        2          2   -0.09
# 5        2          3    1.17
# 5        2          3    1.14
# 5        2          3   -1.79
